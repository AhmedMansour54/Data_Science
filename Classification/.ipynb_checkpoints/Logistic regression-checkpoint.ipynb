# %% [markdown]
# ## About this data
# #### Variables
# - Each attribute is a potential risk factor. There are both demographic, behavioral and medical risk factors.
# #### Demographic:
# - Sex: male or female(Nominal)
# - Age: Age of the patient;(Continuous - Although the recorded ages have been truncated to whole numbers, the concept of age is continuous)
# #### Behavioral
# - Current Smoker: whether or not the patient is a current smoker (Nominal)
# - Cigs Per Day: the number of cigarettes that the person smoked on average in one day.(can be considered continuous as one can have any number of cigarettes, even half a cigarette.)
# #### Medical( history)
# - BP Meds: whether or not the patient was on blood pressure medication (Nominal)
# - Prevalent Stroke: whether or not the patient had previously had a stroke (Nominal)
# - Prevalent Hyp: whether or not the patient was hypertensive (Nominal)
# - Diabetes: whether or not the patient had diabetes (Nominal)
# #### Medical(current)
# - Tot Chol: total cholesterol level (Continuous)
# - Sys BP: systolic blood pressure (Continuous)
# - Dia BP: diastolic blood pressure (Continuous)
# - BMI: Body Mass Index (Continuous)
# - Heart Rate: heart rate (Continuous - In medical research, variables such as heart rate though in fact discrete, yet are considered continuous because of large number of possible values.)
# - Glucose: glucose level (Continuous)
# #### Predict variable (desired target)
# - 10 year risk of coronary heart disease CHD (binary: “1”, means “Yes”, “0” means “No”)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Call Dataset**

# %%
df=pd.read_csv('framingham.csv',sep=',')

# %%
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# 1                   0             0         0    250.0  121.0   81.0  28.73
# 2                   0             0         0    245.0  127.5   80.0  25.34
# 3                   0             1         0    225.0  150.0   95.0  28.58
# 4                   0             0         0    285.0  130.0   84.0  23.10
# ...               ...           ...       ...      ...    ...    ...    ...
# 4233                0             1         0    313.0  179.0   92.0  25.97
# 4234                0             0         0    207.0  126.5   80.0  19.71
# 4235                0             0         0    248.0  131.0   72.0  22.00
# 4236                0             0         0    210.0  126.5   87.0  19.16
# 4237                0             0         0    269.0  133.5   83.0  21.47
#
#       heartRate  glucose  TenYearCHD
# 0          80.0     77.0           0
# 1          95.0     76.0           0
# 2          75.0     70.0           0
# 3          65.0    103.0           1
# 4          85.0     85.0           0
# ...         ...      ...         ...
# 4233       66.0     86.0           1
# 4234       65.0     68.0           0
# 4235       84.0     86.0           0
# 4236       86.0      NaN           0
# 4237       80.0    107.0           0
#
# [4238 rows x 16 columns]

# %% [markdown]
# **Describe for data**

# %%
df.describe().T.style.background_gradient()  #cmap = "Spectral"
# Out:
# <style type="text/css">
# #T_916f2_row0_col0, #T_916f2_row1_col0, #T_916f2_row3_col0, #T_916f2_row6_col0, #T_916f2_row7_col0, #T_916f2_row8_col0, #T_916f2_row9_col1, #T_916f2_row9_col2, #T_916f2_row9_col3, #T_916f2_row9_col4, #T_916f2_row9_col5, #T_916f2_row9_col6, #T_916f2_row9_col7, #T_916f2_row10_col0, #T_916f2_row11_col0, #T_916f2_row13_col0, #T_916f2_row15_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_916f2_row0_col1, #T_916f2_row0_col3, #T_916f2_row0_col4, #T_916f2_row0_col5, #T_916f2_row0_col6, #T_916f2_row0_col7, #T_916f2_row3_col1, #T_916f2_row3_col3, #T_916f2_row3_col4, #T_916f2_row3_col5, #T_916f2_row3_col6, #T_916f2_row3_col7, #T_916f2_row4_col3, #T_916f2_row4_col4, #T_916f2_row4_col5, #T_916f2_row5_col1, #T_916f2_row5_col2, #T_916f2_row5_col3, #T_916f2_row5_col4, #T_916f2_row5_col5, #T_916f2_row5_col6, #T_916f2_row5_col7, #T_916f2_row6_col1, #T_916f2_row6_col2, #T_916f2_row6_col3, #T_916f2_row6_col4, #T_916f2_row6_col5, #T_916f2_row6_col6, #T_916f2_row6_col7, #T_916f2_row7_col1, #T_916f2_row7_col3, #T_916f2_row7_col4, #T_916f2_row7_col5, #T_916f2_row7_col6, #T_916f2_row7_col7, #T_916f2_row8_col1, #T_916f2_row8_col2, #T_916f2_row8_col3, #T_916f2_row8_col4, #T_916f2_row8_col5, #T_916f2_row8_col6, #T_916f2_row8_col7, #T_916f2_row14_col0, #T_916f2_row15_col1, #T_916f2_row15_col3, #T_916f2_row15_col4, #T_916f2_row15_col5, #T_916f2_row15_col6, #T_916f2_row15_col7 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_916f2_row0_col2, #T_916f2_row2_col1, #T_916f2_row2_col3, #T_916f2_row2_col5, #T_916f2_row2_col6, #T_916f2_row3_col2, #T_916f2_row7_col2 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_916f2_row1_col1, #T_916f2_row1_col5, #T_916f2_row1_col6 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_916f2_row1_col2 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_916f2_row1_col3 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_916f2_row1_col4, #T_916f2_row11_col7, #T_916f2_row13_col7 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_916f2_row1_col7, #T_916f2_row4_col7 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_916f2_row2_col0 {
#   background-color: #0d75b3;
#   color: #f1f1f1;
# }
# #T_916f2_row2_col2 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_916f2_row2_col4, #T_916f2_row2_col7, #T_916f2_row15_col2 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_916f2_row4_col0 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_916f2_row4_col1 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_916f2_row4_col2, #T_916f2_row11_col2, #T_916f2_row13_col2 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_916f2_row4_col6 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_916f2_row5_col0 {
#   background-color: #045b8f;
#   color: #f1f1f1;
# }
# #T_916f2_row9_col0 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_916f2_row10_col1 {
#   background-color: #569dc8;
#   color: #f1f1f1;
# }
# #T_916f2_row10_col2 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# #T_916f2_row10_col3 {
#   background-color: #056ba7;
#   color: #f1f1f1;
# }
# #T_916f2_row10_col4 {
#   background-color: #529bc7;
#   color: #f1f1f1;
# }
# #T_916f2_row10_col5, #T_916f2_row10_col6 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_916f2_row10_col7 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_916f2_row11_col1, #T_916f2_row11_col5 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_916f2_row11_col3 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_916f2_row11_col4 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_916f2_row11_col6 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_916f2_row12_col0 {
#   background-color: #03456c;
#   color: #f1f1f1;
# }
# #T_916f2_row12_col1, #T_916f2_row12_col5, #T_916f2_row12_col6 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_916f2_row12_col2 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_916f2_row12_col3 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_916f2_row12_col4 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_916f2_row12_col7 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_916f2_row13_col1, #T_916f2_row13_col5 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_916f2_row13_col3 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_916f2_row13_col4, #T_916f2_row14_col6 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_916f2_row13_col6 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_916f2_row14_col1, #T_916f2_row14_col4 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_916f2_row14_col2 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_916f2_row14_col3 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_916f2_row14_col5 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_916f2_row14_col7 {
#   background-color: #549cc7;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_916f2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_916f2_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_916f2_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_916f2_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_916f2_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_916f2_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_916f2_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_916f2_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_916f2_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_916f2_level0_row0" class="row_heading level0 row0" >male</th>
#       <td id="T_916f2_row0_col0" class="data row0 col0" >4238.000000</td>
#       <td id="T_916f2_row0_col1" class="data row0 col1" >0.429212</td>
#       <td id="T_916f2_row0_col2" class="data row0 col2" >0.495022</td>
#       <td id="T_916f2_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_916f2_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_916f2_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_916f2_row0_col6" class="data row0 col6" >1.000000</td>
#       <td id="T_916f2_row0_col7" class="data row0 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_916f2_level0_row1" class="row_heading level0 row1" >age</th>
#       <td id="T_916f2_row1_col0" class="data row1 col0" >4238.000000</td>
#       <td id="T_916f2_row1_col1" class="data row1 col1" >49.584946</td>
#       <td id="T_916f2_row1_col2" class="data row1 col2" >8.572160</td>
#       <td id="T_916f2_row1_col3" class="data row1 col3" >32.000000</td>
#       <td id="T_916f2_row1_col4" class="data row1 col4" >42.000000</td>
#       <td id="T_916f2_row1_col5" class="data row1 col5" >49.000000</td>
#       <td id="T_916f2_row1_col6" class="data row1 col6" >56.000000</td>
#       <td id="T_916f2_row1_col7" class="data row1 col7" >70.000000</td>
#     </tr>
#     <tr>
#       <th id="T_916f2_level0_row2" class="row_heading level0 row2" >education</th>
#       <td id="T_916f2_row2_col0" class="data row2 col0" >4133.000000</td>
#       <td id="T_916f2_row2_col1" class="data row2 col1" >1.978950</td>
#       <td id="T_916f2_row2_col2" class="data row2 col2" >1.019791</td>
#       <td id="T_916f2_row2_col3" class="data row2 col3" >1.000000</td>
#       <td id="T_916f2_row2_col4" class="data row2 col4" >1.000000</td>
#       <td id="T_916f2_row2_col5" class="data row2 col5" >2.000000</td>
#       <td id="T_916f2_row2_col6" class="data row2 col6" >3.000000</td>
#       <td id="T_916f2_row2_col7" class="data row2 col7" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_916f2_level0_row3" class="row_heading level0 row3" >currentSmoker</th>
#       <td id="T_916f2_row3_col0" class="data row3 col0" >4238.000000</td>
#       <td id="T_916f2_row3_col1" class="data row3 col1" >0.494101</td>
#       <td id="T_916f2_row3_col2" class="data row3 col2" >0.500024</td>
#       <td id="T_916f2_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_916f2_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_916f2_row3_col5" class="data row3 col5" >

# %% [markdown]
# **Get Information about data**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4238 entries, 0 to 4237
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4238 non-null   int64
#  1   age              4238 non-null   int64
#  2   education        4133 non-null   float64
#  3   currentSmoker    4238 non-null   int64
#  4   cigsPerDay       4209 non-null   float64
#  5   BPMeds           4185 non-null   float64
#  6   prevalentStroke  4238 non-null   int64
#  7   prevalentHyp     4238 non-null   int64
#  8   diabetes         4238 non-null   int64
#  9   totChol          4188 non-null   float64
#  10  sysBP            4238 non-null   float64
#  11  diaBP            4238 non-null   float64
#  12  BMI              4219 non-null   float64
#  13  heartRate        4237 non-null   float64
#  14  glucose          3850 non-null   float64
#  15  TenYearCHD       4238 non-null   int64
# dtypes: float64(9), int64(7)
# memory usage: 529.9 KB

# %% [markdown]
# **Get features of data**

# %%
df.columns
# Out:
# Index(['male', 'age', 'education', 'currentSmoker', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD'],
#       dtype='object')

# %% [markdown]
# **Get values for each feature**

# %%
for i in df.columns:
  print('-'*40)
  print(i)
  print(df[i].value_counts())
  print('*'*40)
# Out:
# ----------------------------------------
# male
# 0    2419
# 1    1819
# Name: male, dtype: int64
# ****************************************
# ----------------------------------------
# age
# 40    191
# 46    182
# 42    180
# 41    174
# 48    173
# 39    169
# 44    166
# 45    162
# 43    159
# 52    149
# 51    146
# 55    145
# 38    144
# 47    141
# 50    140
# 53    139
# 54    132
# 49    132
# 57    123
# 56    123
# 59    119
# 58    117
# 60    111
# 63    110
# 61    110
# 62     99
# 64     93
# 37     92
# 36     84
# 65     57
# 67     45
# 35     42
# 66     38
# 34     18
# 68     18
# 69      7
# 33      5
# 70      2
# 32      1
# Name: age, dtype: int64
# ****************************************
# ----------------------------------------
# education
# 1.0    1720
# 2.0    1253
# 3.0     687
# 4.0     473
# Name: education, dtype: int64
# ****************************************
# ----------------------------------------
# currentSmoker
# 0    2144
# 1    2094
# Name: currentSmoker, dtype: int64
# ****************************************
# ----------------------------------------
# cigsPerDay
# 0.0     2144
# 20.0     734
# 30.0     217
# 15.0     210
# 10.0     143
# 9.0      130
# 5.0      121
# 3.0      100
# 40.0      80
# 1.0       67
# 43.0      56
# 25.0      55
# 35.0      22
# 2.0       18
# 6.0       18
# 7.0       12
# 8.0       11
# 60.0      11
# 4.0        9
# 18.0       8
# 17.0       7
# 50.0       6
# 23.0       6
# 11.0       5
# 45.0       3
# 13.0       3
# 12.0       3
# 16.0       3
# 14.0       2
# 19.0       2
# 38.0       1
# 29.0       1
# 70.0       1
# Name: cigsPerDay, dtype: int64
# ****************************************
# ----------------------------------------
# BPMeds
# 0.0    4061
# 1.0     124
# Name: BPMeds, dtype: int64
# ****************************************
# ----------------------------------------
# prevalentStroke
# 0    4213
# 1      25
# Name: prevalentStroke, dtype: int64
# ****************************************
# ----------------------------------------
# prevalentHyp
# 0    2922
# 1    1316
# Name: prevalentHyp, dtype: int64
# ****************************************
# ----------------------------------------
# diabetes
# 0    4129
# 1     109
# Name: diabetes, dtype: int64
# ****************************************
# ----------------------------------------
# totChol
# 240.0    85
# 220.0    70
# 260.0    62
# 210.0    61
# 232.0    59
#          ..
# 392.0     1
# 405.0     1
# 359.0     1
# 398.0     1
# 119.0     1
# Name: totChol, Length: 248, dtype: int64
# ****************************************
# ----------------------------------------
# sysBP
# 120.0    107
# 130.0    102
# 110.0     96
# 115.0     89
# 125.0     88
#         ...
# 169.5      1
# 98.5       1
# 181.5      1
# 188.5      1
# 207.0      1
# Name: sysBP, Length: 234, dtype: int64
# ****************************************
# ----------------------------------------
# diaBP
# 80.0     262
# 82.0     152
# 85.0     137
# 70.0     135
# 81.0     131
#         ...
# 132.0      1
# 54.0       1
# 142.5      1
# 116.5      1
# 127.5      1
# Name: diaBP, Length: 146, dtype: int64
# ****************************************
# ----------------------------------------
# BMI
# 22.19    18
# 22.54    18
# 23.48    18
# 22.91    18
# 23.09    16
#          ..
# 34.13     1
# 23.21     1
# 29.13     1
# 19.87     1
# 43.67     1
# Name: BMI, Length: 1363, dtype: int64
# ****************************************
# ----------------------------------------
# heartRate
# 75.0     563
# 80.0     385
# 70.0     305
# 60.0     231
# 85.0     227
#         ...
# 47.0       1
# 130.0      1
# 140.0      1
# 51.0       1
# 46.0       1
# Name: heartRate, Length: 73, dtype: int64
# ****************************************
# ----------------------------------------
# glucose
# 75.0     193
# 77.0     167
# 73.0     156
# 80.0     152
# 70.0     152
#         ...
# 386.0      1
# 155.0      1
# 147.0      1
# 205.0      1
# 260.0      1
# Name: glucose, Length: 143, dtype: int64
# ****************************************
# ----------------------------------------
# TenYearCHD
# 0    3594
# 1     644
# Name: TenYearCHD, dtype: int64
# ****************************************

# %% [markdown]
# **Known feature that has values equal null**

# %%
df.isnull().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
sns.heatmap(df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Fill missing values**

# %%
df['education'].fillna(df['education'].median(),inplace=True)

# %%
df['cigsPerDay'].fillna(int(df['cigsPerDay'].mean()),inplace=True)

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='median')
df['BPMeds']=imputer.fit_transform(df[['BPMeds']])

# %%
df['totChol'].fillna(df['totChol'].median(),inplace=True)

# %%
df['BMI'].fillna(df['BMI'].median(),inplace=True)

# %%
df['heartRate'].fillna(df['heartRate'].median(),inplace=True)

# %%
df['glucose'].fillna(int(df['glucose'].mean()),inplace=True)

# %%
df.isnull().sum()
# Out:
# male               0
# age                0
# education          0
# currentSmoker      0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# TenYearCHD         0
# dtype: int64

# %% [markdown]
# ### Data Preprocessing & Visualization
# **deal with data outlier**
# <br>**deal with imbalance data**

# %%
plt.figure(figsize = (15,6))
df.boxplot(rot=45)
# Out:
# <AxesSubplot:>

# %%
sns.histplot(data=df, x= "glucose", kde=True)
# Out:
# <AxesSubplot:xlabel='glucose', ylabel='Count'>

# %%
from scipy.stats import skew

# %%
for i in df:
  print('-'*40)
  print(i)
  print(skew(df[i]))
  plt.figure()
  sns.distplot(df[i])
  plt.show()
  print('*'*40)
# Out:
# ----------------------------------------
# male
# 0.2860335437078504
# ****************************************
# ----------------------------------------
# age
# 0.22806501927587203
# ****************************************
# ----------------------------------------
# education
# 0.6969245219700375
# ****************************************
# ----------------------------------------
# currentSmoker
# 0.023597678241622375
# ****************************************
# ----------------------------------------
# cigsPerDay
# 1.2517606054039054
# ****************************************
# ----------------------------------------
# BPMeds
# 5.586372735223755
# ****************************************
# ----------------------------------------
# prevalentStroke
# 12.904492784056524
# ****************************************
# ----------------------------------------
# prevalentHyp
# 0.8189879096327174
# ****************************************
# ----------------------------------------
# diabetes
# 5.99225605166314
# ****************************************
# ----------------------------------------
# totChol
# 0.8784073145784838
# ****************************************
# ----------------------------------------
# sysBP
# 1.1449567062594848
# ****************************************
# ----------------------------------------
# diaBP
# 0.7138494094062997
# ****************************************
# ----------------------------------------
# BMI
# 0.9850927407330611
# ****************************************
# ----------------------------------------
# heartRate
# 0.6443800064756061
# ****************************************
# ----------------------------------------
# glucose
# 6.526602280134371
# ****************************************
# ----------------------------------------
# TenYearCHD
# 1.9390546347112285
# ****************************************

# %%
sns.boxplot(data= df, x = "totChol")
sns.stripplot(x='totChol', data=df, color="#474646")
# Out:
# <AxesSubplot:xlabel='totChol'>

# %%
from datasist.structdata import detect_outliers
outliers_indices = detect_outliers(df, 0,df[['totChol']])
print(len(outliers_indices))
df.drop(outliers_indices, inplace=True)
# Out:
# 57

# %%
sns.boxplot(data= df, x = "sysBP")
sns.stripplot(x='sysBP', data=df, color="#474646")
# Out:
# <AxesSubplot:xlabel='sysBP'>

# %%
df=df[df['sysBP']<200]

# %%
sns.boxplot(data= df, x = "diaBP")
sns.stripplot(x='diaBP', data=df, color="#474646")
# Out:
# <AxesSubplot:xlabel='diaBP'>

# %%
df=df[df['diaBP']<115]

# %%
sns.boxplot(data= df, x = "BMI")
sns.stripplot(x='BMI', data=df, color="#474646")
# Out:
# <AxesSubplot:xlabel='BMI'>

# %%
df=df[df['BMI']<38]

# %%
sns.boxplot(data= df, x = "heartRate")
sns.stripplot(x='heartRate', data=df, color="#474646")
# Out:
# <AxesSubplot:xlabel='heartRate'>

# %%
df=df[df['heartRate']<108]

# %%
sns.boxplot(data= df, x = "glucose")
# Out:
# <AxesSubplot:xlabel='glucose'>

# %%
df=df[df['glucose']<140]

# %%
plt.figure(figsize = (15,6))
df.boxplot(rot=45)
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['male', 'age', 'education', 'currentSmoker', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD'],
#       dtype='object')

# %%
c=['male', 'age', 'education', 'currentSmoker']

fig, ax = plt.subplots(nrows = 2,ncols =2,figsize = (13,12))
for i in range(len(c)):
    plt.subplot(2,2,i+1)
    sns.histplot(data=df,x=df[c[i]], color='teal',edgecolor="white", linewidth=0.7)

# %%
plt.figure(figsize=(9,7))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
# plt.subplot(151)
sns.boxplot(y = "glucose", x = "TenYearCHD", data = df)
sns.stripplot(y = "glucose", x = "TenYearCHD", data = df, palette="dark")
# Out:
# <AxesSubplot:xlabel='TenYearCHD', ylabel='glucose'>

# %%
plt.figure(figsize = (20,6))
cl=['totChol', 'sysBP','diaBP', 'BMI', 'heartRate']
t='TenYearCHD'
index=1
for i in cl:
    plt.subplot(1,5,index)
    sns.boxplot(y = i, x = t, data = df)
    sns.stripplot(y = i, x = t, data = df, palette="dark")
    index += 1

# %% [markdown]
# **Imbalance data**

# %%
sns.countplot(x=df['TenYearCHD'])
# Out:
# <AxesSubplot:xlabel='TenYearCHD', ylabel='count'>

# %%
from sklearn.utils import resample
#create two different dataframe of majority and minority class 
df_majority = df[(df['TenYearCHD']==0)] 
df_minority_ = df[(df['TenYearCHD']==1)] 
# upsample minority class
df_minority_upsampled = resample(df_minority_, 
                                 replace=True,    # sample with replacement
                                 n_samples= len(df_majority), # to match majority class
                                 random_state=42)  # reproducible results
# Combine majority class with upsampled minority class
dff = pd.concat([df_minority_upsampled, df_majority])

# %%
sns.countplot(x=dff['TenYearCHD'])
# Out:
# <AxesSubplot:xlabel='TenYearCHD', ylabel='count'>

# %% [markdown]
# **Divide data to attribute(feature) & target**

# %%
X=dff.drop(['TenYearCHD'], axis=1)
y=dff['TenYearCHD']

# %%
X
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 689      1   64        1.0              1        18.0     0.0
# 3363     0   66        1.0              0         0.0     0.0
# 2087     1   57        3.0              0         0.0     0.0
# 734      1   44        1.0              1        30.0     0.0
# 471      1   61        1.0              0         0.0     1.0
# ...    ...  ...        ...            ...         ...     ...
# 4231     1   58        3.0              0         0.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     0.0
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 689                 0             1         0    219.0  172.5   75.0  29.29
# 3363                0             1         0    312.0  150.0   74.0  25.59
# 2087                0             0         0    213.0  141.0   90.0  30.77
# 734                 0             0         0    334.0  131.0   74.0  28.82
# 471                 0             1         1    270.0  177.5   95.0  28.15
# ...               ...           ...       ...      ...    ...    ...    ...
# 4231                0             1         0    187.0  141.0   81.0  24.96
# 4234                0             0         0    207.0  126.5   80.0  19.71
# 4235                0             0         0    248.0  131.0   72.0  22.00
# 4236                0             0         0    210.0  126.5   87.0  19.16
# 4237                0             0         0    269.0  133.5   83.0  21.47
#
#       heartRate  glucose
# 689        75.0     91.0
# 3363       72.0     90.0
# 2087       60.0     77.0
# 734        80.0     77.0
# 471        62.0    123.0
# ...         ...      ...
# 4231       80.0     81.0
# 4234       65.0     68.0
# 4235       84.0     86.0
# 4236       86.0     81.0
# 4237       80.0    107.0
#
# [6796 rows x 15 columns]

# %%
col=X.columns
col
# Out:
# Index(['male', 'age', 'education', 'currentSmoker', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose'],
#       dtype='object')

# %% [markdown]
# **Make Scaler for data**

# %%
from sklearn.preprocessing import MinMaxScaler
ms = MinMaxScaler()
X = ms.fit_transform(X)
X = pd.DataFrame(X, columns=col)

# %%
X.shape
# Out:
# (6796, 15)

# %% [markdown]
# ### Train test split & Get models

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(X,y , test_size= 0.20 , random_state= 42)

# %% [markdown]
# #### Logistic Reression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lg = LogisticRegression()

# %%
lg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lg.score(x_train , y_train)
# Out:
# 0.6659308314937454

# %%
lg.score(x_test , y_test)
# Out:
# 0.6544117647058824

# %%
y_pred =lg.predict(x_test)

# %%
dataf= pd.DataFrame({"Y_test": y_test , "Y_pred" : y_pred})
dataf.head(20)
# Out:
#       Y_test  Y_pred
# 2748       0       0
# 1855       1       1
# 3962       1       1
# 3018       0       1
# 2804       0       0
# 2685       0       0
# 1027       1       1
# 2841       0       1
# 567        0       1
# 1986       1       1
# 1675       1       1
# 3774       0       0
# 2633       1       0
# 33         1       1
# 3979       1       0
# 2439       0       0
# 2873       0       1
# 3390       0       0
# 3946       0       1
# 691        0       1

# %%
lg.intercept_
# Out:
# array([-2.73269854])

# %%
lg.coef_
# Out:
# array([[ 0.56817979,  2.64483547, -0.06345831,  0.22244882,  1.15236387,
#          0.26755872,  0.68934782,  0.29705007, -0.31672834,  0.50958117,
#          1.45532896, -0.41863581,  0.07915078, -0.12063233,  0.13792844]])

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
confusion_matrix(y_test, y_pred)
# Out:
# array([[445, 215],
#        [255, 445]], dtype=int64)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.6544117647058824

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.67      0.65       660
#            1       0.67      0.64      0.65       700
#
#     accuracy                           0.65      1360
#    macro avg       0.65      0.65      0.65      1360
# weighted avg       0.66      0.65      0.65      1360

# %%
from sklearn.model_selection import cross_val_score

# %%
cross_val_score(LogisticRegression(solver='liblinear',multi_class='ovr'), X, y,cv=10)
# Out:
# array([0.67647059, 0.67205882, 0.64705882, 0.67794118, 0.66176471,
#        0.7       , 0.65684831, 0.67157585, 0.64801178, 0.66568483])

# %%
from sklearn.model_selection import cross_val_score,KFold,LeavePOut
from sklearn.ensemble import RandomForestClassifier

# %%
kf=KFold(n_splits=5)
score=cross_val_score(lg,X,y,cv=kf)
print("Cross Validation Scores are {}".format(score))
print("Average Cross Validation score :{}".format(score.mean()))
# Out:
# Cross Validation Scores are [0.43235294 0.45989698 0.68138337 0.44297277 0.44591611]
# Average Cross Validation score :0.4925044366532485

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import ShuffleSplit, cross_val_score ,LeaveOneOut

# %%
clf = DecisionTreeClassifier(random_state=42)
ss = ShuffleSplit(train_size=0.75, test_size=0.25, n_splits = 10)

scores = cross_val_score(clf, X, y, cv = ss)

print("Cross Validation Scores: ", scores)
print("Average CV Score: ", scores.mean())
print("Number of CV Scores used in Average: ", len(scores))
# Out:
# Cross Validation Scores:  [0.91936433 0.91818717 0.9234844  0.90935845 0.91288994 0.91583284
#  0.91288994 0.91936433 0.92289582 0.90876986]
# Average CV Score:  0.9163037080635668
# Number of CV Scores used in Average:  10

# %% [markdown]
# ### K-Nighbors Classifer Model

# %%
from sklearn.neighbors import KNeighborsClassifier
knn =  KNeighborsClassifier(n_neighbors=3 , metric="manhattan"  )

# %%
knn.fit(x_train , y_train )
# Out:
# KNeighborsClassifier(metric='manhattan', n_neighbors=3)

# %%
knn.score(x_train , y_train )
# Out:
# 0.9288079470198676

# %%
knn.score(x_test , y_test )
# Out:
# 0.8757352941176471

# %%
y_pred =knn.predict(x_test)

# %%
dataf= pd.DataFrame({"Y_test": y_test , "Y_pred" : y_pred})
dataf.head(20)
# Out:
#       Y_test  Y_pred
# 2748       0       0
# 1855       1       1
# 3962       1       1
# 3018       0       0
# 2804       0       0
# 2685       0       1
# 1027       1       1
# 2841       0       1
# 567        0       1
# 1986       1       1
# 1675       1       1
# 3774       0       0
# 2633       1       1
# 33         1       1
# 3979       1       1
# 2439       0       0
# 2873       0       0
# 3390       0       0
# 3946       0       0
# 691        0       0

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[503, 157],
#        [ 12, 688]], dtype=int64)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.76      0.86       660
#            1       0.81      0.98      0.89       700
#
#     accuracy                           0.88      1360
#    macro avg       0.90      0.87      0.87      1360
# weighted avg       0.89      0.88      0.87      1360

# %%
from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 23.52222222222222, 'Predicted label')

# %%
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr, label='Knn')
plt.xlabel('fpr')
plt.ylabel('tpr')
plt.title('Knn(n_neighbors=11) ROC curve')
plt.show()

# %% [markdown]
# ### Thank!
